# %%
print("Hello from the test notebook!")
# Out:
# Hello from the test notebook!

# %%
import pandas as pd
def test(): 
    df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
    print(df)
if __name__ == "__main__":    test()
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
